# %% [markdown]
# # Ideas
# - La importancia de la tasa de cambio no oficial y como esta afecta a la capacidad de compra de los cubanos.
# - Impacto de la tasa de cambio no oficial en el precio de los alimentos y otros articulos de primera necesidad.
# - Quizas mostrar la correlacion que existe entre el precio de algunos productos y la tasa de cambio no oficial(el precio del aceite varia en 0.2 por cada X pesos cubanos que sube el dolar).
# - Analisis del impacto de la tasa de cambio informal en los precios de productos basicos de mipymes en La Habana
# -  Como afecta la tasa de cambio no oficial a los precios de los productos importados que ofrecen las mipymes
# - Como afecta la tasa de cambio no oficial al precio de los productos de primera necesidad dentro del sector privado
# - Que le ocurre al precio de los electrodomésticos cuando varia la tasa de cambio no oficial
# - Que productos son los más sensibles a los cambios en la tasa de cambio no oficial
# - El precio de los alimentos importados aumentan al mismo ritmo que la tasa de cambio no oficial
# - Que influencia tiene la tasa de cambio no oficial de algunos sitios en los precios que se ve en los grupos de compraventa
# - La ubicación del negocio influye en los precios
# - Que estrategias usan las mipymes para poner precios cuando la tasa de cambio está constantemente variando
# - La ubicación del negocio influye en los precios?
# - Hay alguna relación entre la inflación y la tasa de cambio no oficial?
# - A parte del tipo de cambio, ¿qué otros factores explican el aumento de los precios?
# - Como afecta la tasa de cambio no oficial al poder adquisitivo de la población?
# - Como influye la tasa de cambio no oficial al acceso a productos y necesidades básicas
#
# [Esto es un enlace](markdown.es/sintaxis-markdown/)
#
# ![Esto es una imagen](markdown.es/sintaxis-markdown/)
#
# ```py
# #code
# ```
#
# $formula$
#
# $$formula  compleja$$

# %%
import  Functions as fnc

data_of_a_town = fnc.filter_by("township","Habana del Este")
mipymes_quantity = len(fnc.get_keys())
for i in data_of_a_town:
    print(i)
# Out:
# galletas rellenitas
# galletas dode deleite
# chocolate/almendra
# galletas caramelo chocolate
# galletas caramelo vainilla
# bombones
# galletas kremali
# galletas saltitacos
# pelly de jamon
# chupa chupa
# gomitas
# sorbeto mega
# panque today
# galletas bigs
# refresco importado
# cerveza presidente
# cerveza lobo
# jabon ridel
# jabon ridel leche y miel
# jabon harmony
# cerveza beer
# papel higienico
# picadillo de pollo(m.d.m)
# mostaza
# cafe santa barbara
# sal
# refresco fresh
# hamburgesa
# salchicha
# azucar blanca
# spaguettis
# pasta de tomate
# mortadella de pollo
# arroz bolsa
# ----------------
# jamon viking
# jamon embuchado
# lomo deshuesado ahumado
# molleja pollo
# pierna deshuesada
# recorteria ahumada
# chorizo criollo
# chorizo especial
# chorizo vela
# pollo ahumado
# picadillo de pollo
# higado de cerdo
# jamonada especial de pollo
# potajin
# albondigas
# croquetas
# quezo gouda
# ----------------
# bandeja de lomo ahumado
# medallones
# picadillo mdm
# ...

# %%
import Functions as fnc

mipymes = fnc.get_keys()
data = fnc.load_json()
data_by_product = fnc.filter_by("mipyme","Agro-Plaza")

print(data_by_product)
price_data_by_product = [x[1] for x in data_by_product]
print(sorted(price_data_by_product))
print("median:",fnc.calculate_statistics(price_data_by_product)["median"])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 5
#       3 mipymes = fnc.get_keys()
#       4 data = fnc.load_json()
# ----> 5 data_by_product = fnc.filter_by("mipyme","Agro-Plaza")
#       7 print(data_by_product)
#       8 price_data_by_product = [x[1] for x in data_by_product]
#
# File /media/amnesiac/almacenamiento/Proyectos/Ciencia de Datos/Proyecto Primer Semestre Ciencia de Datos/Functions.py:74, in filter_by(category, value)
#      69 def filter_by(category, value):
#      70     #to isolate data
#      71     #all data of a mipyme
#      72     #all prices of a product
#      73     #all products in a township
# ---> 74     data_list = data_to_list()
#      75     filtred_list = []
#      76     if category == "product":
#
# ...

# %%
import Functions as fnc

filter_product = fnc.filter_by("product","aceite")

for i in filter_product:
    print("price",': ',i["price"],sep='')
    print("exchange_rate",': ',i["exchange_rate"],sep='')
    print("township",': ',i["township"],sep='')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 import Functions as fnc
# ----> 3 filter_product = fnc.filter_by("product","aceite")
#       5 for i in filter_product:
#       6     print("price",': ',i["price"],sep='')
#
# File /media/amnesiac/almacenamiento/Proyectos/Ciencia de Datos/Proyecto Primer Semestre Ciencia de Datos/Functions.py:74, in filter_by(category, value)
#      69 def filter_by(category, value):
#      70     #to isolate data
#      71     #all data of a mipyme
#      72     #all prices of a product
#      73     #all products in a township
# ---> 74     data_list = data_to_list()
#      75     filtred_list = []
#      76     if category == "product":
#
# File /media/amnesiac/almacenamiento/Proyectos/Ciencia de Datos/Proyecto Primer Semestre Ciencia de Datos/Functions.py:55, in data_to_list()
# ...
