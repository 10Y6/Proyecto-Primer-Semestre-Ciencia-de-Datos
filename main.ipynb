# %% [markdown]
# # Ideas
#
# - La importancia de la tasa de cambio no oficial y como esta afecta a la capacidad de compra de los cubanos.
#
# - Impacto de la tasa de cambio no oficial en el precio de los alimentos y otros articulos de primera necesidad.
#
# - Quizas mostrar la correlacion que existe entre el precio de algunos productos y la tasa de cambio no oficial(el precio del aceite varia en 0.2 por cada X pesos cubanos que sube el dolar).
#
# - Analisis del impacto de la tasa de cambio informal en los precios de productos basicos de mipymes en La Habana
#
# [Esto es un enlace](markdown.es/sintaxis-markdown/)
#
# ![Esto es una imagen](markdown.es/sintaxis-markdown/)
#
# ```py
# #code
# ```
#
# $formula$
#
# $$formula  compleja$$

# %%
import  Functions as fnc

data_of_a_town = fnc.filter_by("township","Habana del Este")
mipymes_quantity = len(fnc.get_keys())
for i in data_of_a_town:
    print(i)
# Out:
# {'product': 'Arroz', 'price': '295', 'exchange_rate': '368', 'mipyme_name': 'Mercado Alamar'}
# {'product': 'Aceite', 'price': '770', 'exchange_rate': '368', 'mipyme_name': 'Mercado Alamar'}
# {'product': 'Azúcar', 'price': '220', 'exchange_rate': '368', 'mipyme_name': 'Mercado Alamar'}
# {'product': 'Leche en Polvo', 'price': '1350', 'exchange_rate': '368', 'mipyme_name': 'Mercado Alamar'}
# {'product': 'Café', 'price': '1070', 'exchange_rate': '368', 'mipyme_name': 'Mercado Alamar'}
# {'product': 'Chocolate', 'price': '800', 'exchange_rate': '368', 'mipyme_name': 'Mercado Alamar'}
# {'product': 'Galletas', 'price': '300', 'exchange_rate': '368', 'mipyme_name': 'Mercado Alamar'}
# {'product': 'Pan', 'price': '210', 'exchange_rate': '368', 'mipyme_name': 'Mercado Alamar'}
# {'product': 'Mermelada', 'price': '520', 'exchange_rate': '368', 'mipyme_name': 'Mercado Alamar'}
# {'product': 'Mantequilla', 'price': '820', 'exchange_rate': '368', 'mipyme_name': 'Mercado Alamar'}
# {'product': 'Huevos', 'price': '54', 'exchange_rate': '368', 'mipyme_name': 'Mercado Alamar'}
# {'product': 'Queso', 'price': '1020', 'exchange_rate': '368', 'mipyme_name': 'Mercado Alamar'}
# {'product': 'Arroz', 'price': '320', 'exchange_rate': '403', 'mipyme_name': 'MiPyME Cojímar'}
# {'product': 'Aceite', 'price': '840', 'exchange_rate': '403', 'mipyme_name': 'MiPyME Cojímar'}
# {'product': 'Pollo', 'price': '880', 'exchange_rate': '403', 'mipyme_name': 'MiPyME Cojímar'}
# {'product': 'Frijoles Negros', 'price': '400', 'exchange_rate': '403', 'mipyme_name': 'MiPyME Cojímar'}
# {'product': 'Azúcar', 'price': '245', 'exchange_rate': '403', 'mipyme_name': 'MiPyME Cojímar'}
# {'product': 'Café', 'price': '1150', 'exchange_rate': '403', 'mipyme_name': 'MiPyME Cojímar'}
# {'product': 'Sal', 'price': '125', 'exchange_rate': '403', 'mipyme_name': 'MiPyME Cojímar'}
# {'product': 'Detergente', 'price': '520', 'exchange_rate': '403', 'mipyme_name': 'MiPyME Cojímar'}
# {'product': 'Jabón', 'price': '130', 'exchange_rate': '403', 'mipyme_name': 'MiPyME Cojímar'}
# {'product': 'Pasta', 'price': '290', 'exchange_rate': '403', 'mipyme_name': 'MiPyME Cojímar'}
# {'product': 'Cebolla', 'price': '160', 'exchange_rate': '403', 'mipyme_name': 'MiPyME Cojímar'}
# {'product': 'Ajo', 'price': '340', 'exchange_rate': '403', 'mipyme_name': 'MiPyME Cojímar'}

# %%
import Functions as fnc

mipymes = fnc.get_keys()
data = fnc.load_json()
data_by_product = fnc.filter_by("mipyme","Agro-Plaza")

print(data_by_product)
price_data_by_product = [x[1] for x in data_by_product]
print(sorted(price_data_by_product))
print("median:",fnc.calculate_statistics(price_data_by_product)["median"])
# Out:
# [('Tomate', 180), ('Cebolla', 165), ('Ajo', 350), ('Pimiento', 160), ('Limón', 145), ('Aguacate', 220), ('Calabaza', 55), ('Pepino', 65), ('Yuca', 70), ('Boniato', 60), ('Malanga', 75), ('Plátano', 90)]
# [55, 60, 65, 70, 75, 90, 145, 160, 165, 180, 220, 350]
# median: 45.0

# %%
import Functions as fnc

filter_product = fnc.filter_by("product","aceite")

for i in filter_product:
    print("price",': ',i["price"],sep='')
    print("exchange_rate",': ',i["exchange_rate"],sep='')
    print("township",': ',i["township"],sep='')
# Out:
# price: 650
# exchange_rate: 335
# township: Centro Habana
# price: 660
# exchange_rate: 338
# township: Habana Vieja
# price: 690
# exchange_rate: 342
# township: Cerro
# price: 700
# exchange_rate: 345
# township: Boyeros
# price: 710
# exchange_rate: 348
# township: Marianao
# price: 720
# exchange_rate: 350
# township: Diez de Octubre
# price: 730
# exchange_rate: 353
# township: San Miguel del Padrón
# price: 740
# exchange_rate: 358
# township: Regla
# price: 750
# exchange_rate: 360
# township: Arroyo Naranjo
# price: 760
# exchange_rate: 365
# township: Guanabacoa
# price: 770
# exchange_rate: 368
# township: Habana del Este
# price: 780
# exchange_rate: 370
# township: Centro Habana
# price: 790
# exchange_rate: 378
# township: Playa
# price: 800
# exchange_rate: 380
# township: Cerro
# price: 810
# exchange_rate: 383
# township: Boyeros
# price: 820
# exchange_rate: 387
# township: Diez de Octubre
# price: 1750
# exchange_rate: 393
# township: Regla
# price: 830
# exchange_rate: 395
# township: Arroyo Naranjo
# price: 840
# exchange_rate: 403
# township: Habana del Este
# price: 850
# exchange_rate: 406
# township: Centro Habana
# price: 860
# exchange_rate: 412
# township: Habana Vieja
