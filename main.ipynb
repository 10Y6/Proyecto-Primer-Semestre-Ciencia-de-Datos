# %% [markdown]
# Ideas
#     -La importancia de la tasa de cambio no oficial y como esta afecta a la capacidad de compra de los cubanos.
#     -Impacto de la tasa de cambio no oficial en el precio de los alimentos y otros articulos de primera necesidad.
#     -Quizas mostrar la correlacion que existe entre el precio de algunos productos y la tasa de cambio no oficial(el precio del aceite varia en 0.2 por cada X pesos cubanos que sube el dolar).

# %% [markdown]
# Formato
# Datos ficticios

# %%
{
"Nombre de Mipyme": {
        "date": "2024-01-15",
        "time": "10:30",
        "geolocation": "23.1136,-82.3666",
        "township": "Centro Habana",
        "products_info": {
            "Products": [
                "Arroz",
                "Aceite Vegetal",
                "Pollo",
                "Azúcar",
                "Leche en Polvo",
                "Pasta",
                "Frijoles Negros",
                "Detergente",
                "Jabón de Baño",
                "Papel Higiénico",
                "Sal",
                "Café"
            ],
            "Prices": [
                "180",
                "450",
                "850",
                "120",
                "1200",
                "200",
                "280",
                "350",
                "80",
                "150",
                "50",
                "800"
            ],
            "Units": [
                "lb",
                "L",
                "lb",
                "lb",
                "kg",
                "paquete 500g",
                "lb",
                "paquete 500g",
                "unidad",
                "rollo",
                "lb",
                "lb"
            ]
        },
        "exchange_rate": "305"
    }
}

# %%
#Probando funciones
import Functions as fnc

mipymes = fnc.get_keys()
data = fnc.load_json()
fnc.print_data_list()
# Out:
# date: 2024-02-25
# time: 10:00
# geolocation: 23.0800,-82.3800
# township: San Miguel del Padrón
# Products_info
# Arroz            210 lb
# Aceite Vegetal   490 L
# Azúcar Refino    140 lb
# Café Molido      850 paquete 250g
# Leche UHT        180 L
# Jugo de Frutas   200 botella 1L
# Galletas Saladas 220 paquete
# Macarrones       240 paquete 500g
# Salsa Boloñesa   450 pomo
# Queso Parmesano  900 paquete 100g
# Sal Fina         60  paquete
# Pimienta Negra   500 pomo
# exchange_rate: 325
