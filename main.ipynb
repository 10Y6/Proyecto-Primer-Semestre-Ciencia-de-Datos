# %% [markdown]
# # Ideas
#
# - La importancia de la tasa de cambio no oficial y como esta afecta a la capacidad de compra de los cubanos.
#
# - Impacto de la tasa de cambio no oficial en el precio de los alimentos y otros articulos de primera necesidad.
#
# - Quizas mostrar la correlacion que existe entre el precio de algunos productos y la tasa de cambio no oficial(el precio del aceite varia en 0.2 por cada X pesos cubanos que sube el dolar).
#
# - Analisis del impacto de la tasa de cambio informal en los precios de productos basicos de mipymes en La Habana
#
# [Esto es un enlace](markdown.es/sintaxis-markdown/)
#
# ![Esto es una imagen](markdown.es/sintaxis-markdown/)
#
# ```py
# #code
# ```
#
# $formula$
#
# $$formula \mono compleja$$

# %%
import  Functions as fnc

data_of_a_town = fnc.filter_by("township","Cotorro")
mipymes_quantity = len(fnc.get_keys())
for i in data_of_a_town:
    print(i)
print(mipymes_quantity)
# Out:
# {'product': 'Yuca', 'price': '70', 'exchange_rate': '363', 'mipyme_name': 'MiPyME El Campo'}
# {'product': 'Malanga', 'price': '75', 'exchange_rate': '363', 'mipyme_name': 'MiPyME El Campo'}
# {'product': 'Boniato', 'price': '60', 'exchange_rate': '363', 'mipyme_name': 'MiPyME El Campo'}
# {'product': 'Plátano Macho', 'price': '85', 'exchange_rate': '363', 'mipyme_name': 'MiPyME El Campo'}
# {'product': 'Plátano Burro', 'price': '95', 'exchange_rate': '363', 'mipyme_name': 'MiPyME El Campo'}
# {'product': 'Calabaza', 'price': '55', 'exchange_rate': '363', 'mipyme_name': 'MiPyME El Campo'}
# {'product': 'Maíz', 'price': '75', 'exchange_rate': '363', 'mipyme_name': 'MiPyME El Campo'}
# {'product': 'Frijoles', 'price': '340', 'exchange_rate': '363', 'mipyme_name': 'MiPyME El Campo'}
# {'product': 'Chicharos', 'price': '380', 'exchange_rate': '363', 'mipyme_name': 'MiPyME El Campo'}
# {'product': 'Habichuelas', 'price': '350', 'exchange_rate': '363', 'mipyme_name': 'MiPyME El Campo'}
# ...

# %%
import Functions as fnc

mipymes = fnc.get_keys()
data = fnc.load_json()
data_by_product = fnc.filter_by("mipyme","Bodega San José")

print(data_by_product)
price_data_by_product = [x[1] for x in data_by_product]
print(sorted(price_data_by_product))
print("median:",fnc.calculate_statistics(price_data_by_product)["median"])
# Out:
# [('Arroz', 265), ('Frijoles Colorados', 370), ('Chicharos', 380), ('Lentejas', 420), ('Aceite', 690), ('Azúcar', 195), ('Sal', 92), ('Vinagre', 180), ('Pasta', 240), ('Atún', 410), ('Sardinas', 320), ('Salsa de Tomate', 210)]
# [92, 180, 195, 210, 240, 265, 320, 370, 380, 410, 420, 690]
# median: 132.5

# %%
import Functions as fnc

filter_product = fnc.filter_by("product","aceite")

for i in filter_product:
    print("price",': ',i["price"],sep='')
    print("exchange_rate",': ',i["exchange_rate"],sep='')
    print("township",': ',i["township"],sep='')
# Out:
# price: 650
# exchange_rate: 335
# township: Centro Habana
# price: 660
# exchange_rate: 338
# township: Habana Vieja
# price: 690
# exchange_rate: 342
# township: Cerro
# price: 700
# exchange_rate: 345
# township: Boyeros
# price: 710
# exchange_rate: 348
# township: Marianao
# price: 720
# exchange_rate: 350
# township: Diez de Octubre
# price: 730
# exchange_rate: 353
# township: San Miguel del Padrón
# price: 740
# exchange_rate: 358
# township: Regla
# price: 750
# exchange_rate: 360
# township: Arroyo Naranjo
# price: 760
# exchange_rate: 365
# township: Guanabacoa
# price: 770
# exchange_rate: 368
# township: Habana del Este
# price: 780
# exchange_rate: 370
# township: Centro Habana
# price: 790
# exchange_rate: 378
# township: Playa
# price: 800
# exchange_rate: 380
# township: Cerro
# price: 810
# exchange_rate: 383
# township: Boyeros
# price: 820
# exchange_rate: 387
# township: Diez de Octubre
# price: 1750
# exchange_rate: 393
# township: Regla
# price: 830
# ...
