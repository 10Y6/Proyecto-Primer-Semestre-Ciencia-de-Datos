# %% [markdown]
# Formato
# Datos ficticios

# %%
{
"Nombre de Mipyme": {
        "date": "2024-01-15",
        "time": "10:30",
        "geolocation": "23.1136,-82.3666",
        "township": "Centro Habana",
        "products_info": {
            "Products": [
                "Arroz",
                "Aceite Vegetal",
                "Pollo",
                "Azúcar",
                "Leche en Polvo",
                "Pasta",
                "Frijoles Negros",
                "Detergente",
                "Jabón de Baño",
                "Papel Higiénico",
                "Sal",
                "Café"
            ],
            "Prices": [
                "180",
                "450",
                "850",
                "120",
                "1200",
                "200",
                "280",
                "350",
                "80",
                "150",
                "50",
                "800"
            ],
            "Units": [
                "lb",
                "L",
                "lb",
                "lb",
                "kg",
                "paquete 500g",
                "lb",
                "paquete 500g",
                "unidad",
                "rollo",
                "lb",
                "lb"
            ]
        },
        "exchange_rate": "305"
    }
}

# %%
#Probando funciones
import Functions as fnc

mipymes = fnc.get_keys()
json = fnc.load_json()

fnc.print_data(mipymes[0])
# Out:
# La Esquina del Sabor
# Bodega El Mambi
# Mercado San José
# Tienda La Bodeguita
# Agromercado Los Pinos
# Mercadito El Rincón
# Tienda Villa Pancho
# La Tienda de Juanito
# Bodega La Caridad
# Supermercado El Progreso
# Mercado La Esperanza
# Tienda Casa Blanca
# Bodega Santa Fe
# Mercadito El Criollo
# Tienda Los Amigos
# Supermercado Mi Tienda
# Bodega El Guajiro
# Mercado La Palma
# Tienda El Manisero
# Bodega Los Pinos Nuevos
# Mercadito La Época
# Supermercado La Abundancia
# Tienda Agropecuaria El Campo
# Bodega El Trigal
# Mercado La Victoria
# Tienda El Buen Gusto
# Bodega Hermanos González
# Supermercado Plaza Nueva
# Tienda Doña Carmen
# Mercado Campesino El Roble
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 7
#       4 mipymes = fnc.get_keys()
#       5 json = fnc.load_json()
# ----> 7 fnc.print_data(mipymes[0])
#
# ...
