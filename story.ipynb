# %% [markdown]
# # Devaluación de la moneda cubana y pérdida de poder adquisitivo. Ánalisis particular a la ciudad de La Habana (2024-2025)
#
# ### Introducción
# La economía cubana atraviesa un periodo de alta incertidumbre caracterizado por un encareciemiento  acelerado y una marcada devaluación del Peso Cubano (CUP) frente a divisas extranjeras en el mercado informal. Este fenómeno impacta directamente en la capacidad de consumo de los hogares, donde los salarios nominales permanecen sin alteraciones mientras los precios de bienes esenciales aumentan.
#
# Este análisis utiliza datos recopilados de fuentes oficiales (ONEI), monitoreo de precios de productos en MIPYMES y publicaciones de redes sociales, y tasas de cambio informales que rigen el mercado.
# > **Nota**:Todos los precios de productos han sido extraidos de lugares y grupos de compra venta de La Habana.
#
# #### Objetivos
# 1.  **Cuantificar** la pérdida real del poder adquisitivo en sectores clave.
# 2.  **Identificar** la correlación entre la tasa de cambio informal y los precios de alimentos.
# 3.  **Determinar** qué productos lideran la inflación.

# %% [markdown]
# ## 1. La Devaluación del Salario Real
# El primer paso es visualizar cuántas canastas básicas puede adquirir un trabajador promedio con su salario íntegro. Se ha tomado como referencia el sector de **Educación**, históricamente uno de los más representativos del empleo estatal.

# %% [markdown]
# Para este estudio se usarará una canasta estandarizada para la subsitencia de un mes para una persona. La canasta modelo incluye:
#
# - Arroz (5.6 kg)
# - Frijoles (1.2 kg)
# - Aceite (1 L)
# - Proteínas (Pollo/Cerdo/Huevo)
#
# Entre otros productos de aseo y alimentación básica.

# %%
# %load_ext autoreload
# %autoreload 2
import visualizations as vs
vs.buy_capacity(sector='Educación')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Análisis de Resultados
#
# La visualización revela una realidad económica crítica para el sector educativo:
#
# **Insuficiencia Salarial**
#
# En ningún punto del periodo analizado (2024-2025) el salario promedio de un maestro logra cubrir siquiera el **50% del costo de una Canasta Básica de Alimentos**. La línea amarilla (que representa el umbral de supervivencia mínima de 1 canasta) se mantiene inalcanzable, evidenciando una pérdida total de la soberanía alimentaria basada únicamente en el salario que gana ejerciendo su profesión.
#
# **Tendencia al Deterioro**
#
# Lejos de recuperarse, la capacidad de compra muestra una tendencia al decrecimiento. Esto indica que los aumentos de precios en el mercado superan cualquier ajuste o estabilidad nominal del salario.
#
# **La Necesidad de Ingresos Externos**
#
# La brecha entre la barra azul (lo que pueden comprar) y la línea amarilla (lo que necesitan para vivir) cuantifica la dependencia de fuentes de ingreso externas para subsistir.
# > **Conclusión:** Para cubrir el 100% de sus necesidades alimentarias básicas, un maestro necesita inyectar a su economía doméstica **más del doble de su salario mensual** proveniente de fuentes externas. El salario nominal ha dejado de ser la fuente principal de sustento.

# %% [markdown]
# ---

# %% [markdown]
# ## 2. La Sombra del Dólar: ¿Varían los precios si cambia el dólar?
#
# Usualmente no es raro escuchar en las calles: *"Si el dólar sube, todo sube"*.
#
# Para poner a prueba esto, hemos cruzado la evolución histórica de la **Tasa de Cambio Informal** contra los precios promedio de dos productos fundamentales: el **arroz** y el **aceite**.
#
# Este gráfico de doble eje nos permite visualizar si los precios de la comida realmente son afectados por el dolar a lo largo de 23 meses (Enero 2024 - Noviembre 2025).

# %%
vs.correlation_dollar()

# %% [markdown]
# ### Análisis de Resultados
#
# El gráfico habla por sí solo y confirma varias cosas:
#
# #### **Existe cierta correlación**
# Casi todo el tiempo, las líneas van de la mano. Si la línea del dolar sube, el arroz y el aceite suben detrás. Es evidente que el precio de la comida depende mucho de a cómo esté el cambio en la calle.
#
# #### **El aumento de Septiembre 2024**
# Aquí pasa algo raro y es que ocurre un pico en el arroz. El dólar estaba tranquilo, incluso bajando un poco, pero el precio del arroz se disparó.
# * Esto coincide con los ciclones y la crisis eléctrica fuerte. Aquí no fue culpa del dólar, fue que simplemente no había arroz. Cuando falta el producto, el precio sube sin importar la tasa de cambio.
#
# #### **Suben rápido, bajan lento**
# Observando entre **Mayo y Julio de 2024**. El dólar tuvo una caída importante y el aceite lo siguió, sin embargo el arroz estuvo casi constante.
#
# > **Conclusión:**
# > El dólar tiene cierta influencia, pero no es el único culpable. La escasez real puede ser peor que la subida de la divisa. Además, cuando un precio sube, se "acomoda" ahí y es muy difícil que baje, aunque el dólar nos de un respiro.

# %% [markdown]
# ---

# %% [markdown]
# ## 3. ¿Cómo han variado los precios desde 2024?
#
# Para entender la **inflación real** que enfrentamos los cubanos, calculamos un **índice de precios base 100**, con la siguiente fórmula:
#
# $$
# \text{Índice} = \frac{\text{Precio Actual}}{\text{Precio Base (Ene 2024)}} \times 100
# $$
# - **Enero 2024 = 100** (precio de referencia)
# - **Mes 'x' 150 = subió 50%** desde enero 2024
#
# Analizamos 5 productos: **aceite, arroz, malta, huevos y cerveza**.
#
# ¿Porqué elegí estos productos?
# - **Aceite** - Importado, posee cieta dependecia al dolar
# - **Arroz** - Producto de consumo diario, alta demanda
# - **Malta** - Bebida popular, producción nacional importante
# - **Cerveza** - Bebida alcohólica casi indispensable en festividades
# - **Huevos** - Proteína asequible, producción nacional mayoritariamente

# %% [markdown]
# > **Tip**: *haz click sobre un producto en la leyenda para aislar su linea*

# %%
vs.total_price_evolution()

# %% [markdown]
# ### Análisis de Resultados: Comportamiento de los Precios
#
# La evolución de los datos recolectados revela dos patrones de comportamiento distintos según el tipo de producto:
#
# #### **Observaciones Generales**
#
# *   **Tendencia a la Subida:**
#     En el **arroz**, el **aceite** y la **cerveza** se observa una clara tendencia al aumento a largo plazo. Estos productos no han regresado a sus precios iniciales, lo que sugiere una inflación o una dependencia de divisas externas.
#
# *   **Precios Oscilantes:**
#     La **malta** y los **huevos** han mostrado un comportamiento más estable en el tiempo, con oscilaciones dentro de ciertos rangos, lo que podría indicar que su precio está más ligado a ciclos de oferta y demanda locales.
#
# #### **Observaciones Particulares**
#
# ##### **Arroz:**
# *   Aumento constante del precio con un **pico evidente en septiembre de 2024**.
# *   **Posibles Causas:**
#     *   **Crisis Energética o factores ambientales:** Septiembre de 2024 estuvo marcado por un déficit severo en la generación eléctrica además de ser un mes de en el que se hace común la aparición de huracanes. Los apagones prolongados pudieron afectar la cadena logística de distribución o producción industrial, encareciendo el producto final.
#     *   **Restrasos en las Importaciones:** Un posible atraso en la llegada de barcos o disminución en la asignación de la canasta podría haber empujado la demanda hacia el mercado informal.
#
# ##### **Aceite:**
# *   Subida del **50% entre febrero y marzo de 2024**, con un nuevo pico en **enero de 2025**.
# *   **Posibles Causas:**
#     *   **Correlación con el Dólar:** Al ser un producto mayoritariamente importado, el salto de feb-mar 2024 podría reflejar un ajuste brusco en la tasa de cambio informal en ese periodo.
#     *   **Indisponibilidad despues de fin de año:** El pico de enero 2025 podría deberse a una baja disponibilidad de inventarios tras las festividades de fin de año, combinada con una alta demanda.
#
# ##### **Malta:**
# *   Valores oscilando entre **210 y 290 CUP** sin cambios estructurales drásticos.
# *   **Posible Causa:**
#     *   **Producción Nacional:** La oferta proviene de la industria nacional mayoritariamente, marcas como Bucanero o Perla Negra son las que normalmente se ofertan en los estableciemientos.
#
# ##### **Huevos:**
# *   Alcanza un **mínimo notable en abril de 2025**.
# *   **Posible Causa:**
#     *   **Disponibilidad de Insumos y Estacionalidad:** Una entrada puntual de alimento animal en los meses previos podría haber estimulado la producción de granjas privadas y estatales para esa fecha, además la primavera suele coincidir con picos naturales en la puesta de huevos de las aves, lo que aumenta la oferta disponible en el mercado.
#
# ##### **Cerveza:**
# *   Subida del 30% (marzo-abril 2024), estabilidad posterior, y subida desbocada en **abril 2025** con picos en **mayo y octubre 2025**, cayendo en junio.
# *   **Posible Causa:**
#     *   **Fechas Festivas:** Fechas festivas como el segundo domingo de mayo, día de las madres, o el 10 y el 20 de octubre,inicio de las luchas por la independencia y dia de la cultura nacional respectivamente, sugieren una inflación impulsada por picos de demanda.
#
# ---

# %% [markdown]
# ## 4. ¿Que tan caóticos son los precios?. ¿Es normal las tendencias a subir como ya vimos anteriormente, o estan caracterizadas por picos y valles de precios?
#
# Este análisis es interesante porque hasta ahora hemos visto cuánto han subido los precios , pero no cómo lo han hecho.
# Para esto se suele utilizar un concepto estadistico básico, el **Coeficiente de Variación (CV)**, y se puede calcular mediante la siguiente fórmula
#
# $$
# \text{CV} = \left(\frac{\text{Desviacón Estandar}}{\text{Media Arimética}} \right) \times 100
# $$
#
# Matemáticamente hablando nos permite diferenciar entre un patron tendencial, es decir subida o caida constante, o un caos en los precios.
#
# Para visualizarlo mejor, he clasificado los productos en tres niveles:
#
# * 🟢 Baja Dispersión (CV < 10%): Precios predecibles.
# * 🟡 Dispersión Moderada (CV 10-20%): Precios oscilantes.
# * 🔴 Alta Dispersión (CV > 20%): Precios caóticos."*

# %%
vs.dispersion_analysis()

# %% [markdown]
# ### Análisis de Resultados
#
# #### **Observaciones Generales**
# *   La primera impresión que nos podríamos llevar es que ningún producto alcanza niveles de dispersión altos, lo cual nos da algo más de contexto si lo analizamos junto al gráfico #3. Sí, efectivamente la tendencia de los precios es aumentar como veíamos anteriormente, pero aumentan de forma no tan caótica, algo que puede ser causado por la inflación natural.
#
# #### **Observaciones Particulares**
#
# *   **Malta:** El producto más estable de los analizados, presentando un coeficiente de variación de **6.83%**. ¿Qué significa? Las maltas más consumidas en la isla son mayormente de producción nacional; las materias primas nacionales por lo general son más baratas y no dependen tanto de la tasa cambiaria del dólar, lo que reduce costos de producción y, por consecuencia, el precio final al consumidor.
#
# *   **Huevos:** El segundo más estable, aunque cerca del **10%**. Los huevos también son productos de producción nacional, aunque las materias primas para producir los huevos (es decir, piensos específicos para gallinas ponedoras, principalmente hechos de soya y maíz) son importados en su mayoría. Lo que justificaría un coeficiente de variación más alto que la malta, causado por posibles retrasos en la obtención de esta materia prima, lo que desembocaría en el retraso o encarecimiento de producción, finalmente ramificándose al precio a los consumidores.
#
# *   **Aceite:** Lo primero a destacar es que su coeficiente de variación del **10.97%** es más estable de lo que se esperaría de un producto de importación que se vuelve casi dólar-dependiente. Esto podría significar varias cosas, y es que si lo relacionamos con la tasa de cambio, se podría decir que el dólar también posee un coeficiente de variación moderado, regido por el incremento sí, pero sin dar saltos bruscos de forma general.
#
# *   **Cerveza:** Con un coeficiente de variación del **15.36%**, la cerveza se ubica en una zona de dispersión media/alta. Su variación podría deberse a que, a diferencia del arroz o el aceite que son productos indispensables, la cerveza es más un producto de recreación, prescindible para la subsistencia (aunque a todos nos guste la cerveza). Como vimos anteriormente, alcanza picos en fechas festivas como mayo y octubre, y se estabiliza en meses sin muchas festividades.
#
# *   **Arroz:** Aquí ya llegamos a un producto cuanto menos interesante. Cuba importa mayormente el arroz que consume; esto nos podría dar una pista de por qué el arroz se lleva la corona si de coeficiente de variación hablamos (alcanzando un **17.43%**). Al ser un ritual el consumo diario del arroz en los hogares cubanos, es un producto con mucha demanda. Agregando a la fórmula los retrasos en importaciones por disímiles factores, además de que las principales zonas de producción nacional ubicadas en el oriente del país (específicamente en Granma) y dado que la época de cosecha del arroz va desde noviembre hasta febrero principalmente, justo después de la temporada ciclónica, y siendo Granma un territorio muy afectado por huracanes y ciclones, las conclusiones son desoladoras.

# %% [markdown]
# ## 5. El Índice del "Congrís con Huevo"
#
# Para terminar este análisis, he decidido dejar de lado los números y centrarnos en uno de los platos representativos de la mesa cubana: **El Congrís con Huevo**.
#
# Este plato no es un lujo. Cuando no hay carnes o viandas, siempre queda el arroz congrís y un huevo frito.
#
# He construido un índice compuesto que suma el costo promedio mensual de los ingredientes necesarios para una ración individual estándar:
#
# - **Arroz:** 115g (aprox. 1/4 de libra)
# - **Frijoles:** 58g (aprox. 1/8 de libra)
# - **Huevo:** 1 unidad
# - **Aceite:** 50ml (para el sofrito y freír los huevos)
#
# ¿Cuánto ha costado sentarse a comer este plato desde enero 2024 hasta noviembre 2025?

# %%
vs.indice_congris_huevo()

# %% [markdown]
# ### Análisis de Resultados
#
# Este gráfico tal vez el más contundente de todo el proyecto. Lejos de ser esperanzador, revela una realidad dura sobre el costo de la subsistencia básica en La Habana.
#
# #### **Tendencia General al alza**
# La tendencia a subir es innegable y preocupante.
# *   En **Enero de 2024**, preparar esta ración costaba alrededor de **350 CUP**.
# *   Para **Noviembre de 2025**, el costo roza los **500 CUP**.
#
# Esto representa un gran aumento. No estamos hablando de productos de lujo, sino de un plato común. Que el costo de un plato tan icónico suba de esta manera mientras los salarios estatales permanecen casi estáticos es un indicador desalentador.
#
# #### **El Pico en Septiembre 2024**
# Se observa un pico en septiembre de 2024, donde el costo se dispara impulsado principalmente por el **Arroz** y el **Aceite**.
# *   Este evento coincide con la crisis energética y la temporada ciclónica mencionada en análisis anteriores.
# *   Lo más impactante es la resistencia a la baja, aunque los precios descendieron levemente después de este evento, nunca regresaron a los niveles de principios de 2024, estableciendo un nuevo piso de precios.
#
# > **Conclusión**
# > El "Congrís con Huevo" ha dejado de ser un plato cotidiano para convertirse en un lujo. Para un trabajador que gana un salario promedio, este plato se vuelve una adquisición considerable.
